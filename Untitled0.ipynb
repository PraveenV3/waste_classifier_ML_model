# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenV3/waste_classifier_ML_model/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Unzip the dataset
# !unzip /content/drive/MyDrive/Dataset/waste_dataset.zip -d /content/dataset/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  /content/drive/MyDrive/Dataset/waste_dataset.zip
#    creating: /content/dataset/mydataset/
#    creating: /content/dataset/mydataset/cardboard/
#   inflating: /content/dataset/mydataset/cardboard/cardboard1.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard10.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard100.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard101.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard102.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard103.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard104.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard105.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard106.jpg
#   inflating: /content/dataset/mydataset/cardboard/cardboard107.jpg
# ...
